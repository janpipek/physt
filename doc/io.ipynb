# %% [markdown]
# ## Special cases

# %% [markdown]
# ### Geant4 analysis tools output

# %%
from physt.compat.geant4 import load_csv

# %%
# %matplotlib inline

# %%
h = load_csv("../tests/data/geant-h1.csv")
h
# Out:
# Histogram1D('Edep in absorber', bins=(100,), total=10000.0, dtype=float64)

# %%
h.plot("line", show_stats=True);
# Out:
# C:\Users\janpi\Documents\code\physt\src\physt\statistics.py:36: RuntimeWarning:
#
# divide by zero encountered in scalar divide

# %%
h2 = load_csv("../tests/data/geant-h2.csv")
h
# Out:
# Histogram1D('Edep in absorber', bins=(100,), total=10000.0, dtype=float64)

# %%
h2.plot(show_zero=False)
# Out:
# <Axes: title={'center': 'Drift Chamber 1 X vs Y'}, xlabel='axis0', ylabel='axis1'>
