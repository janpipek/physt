# %% [markdown]
# ## Special cases

# %% [markdown]
# ### Geant4 analysis tools output

# %%
from physt.compat.geant4 import load_csv

# %%
# %matplotlib inline

# %%
h = load_csv("../tests/data/geant-h1.csv")
h
# Out:
# Histogram1D('Edep in absorber', bins=(100,), total=10000.0, dtype=int64)

# %%
h.plot("line", show_stats=True);

# %%
h2 = load_csv("../tests/data/geant-h2.csv")
h
# Out:
# Histogram1D('Edep in absorber', bins=(100,), total=10000.0, dtype=int64)

# %%
h2.plot(show_zero=False)
# Out:
# <AxesSubplot:title={'center':'Drift Chamber 1 X vs Y'}, xlabel='axis0', ylabel='axis1'>
