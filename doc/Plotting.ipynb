# %% [markdown]
# # Plotting physt histograms

# %%
# Necessary import evil
import physt
from physt import h1, h2, histogramdd
import numpy as np
import matplotlib.pyplot as plt
import seaborn.apionly as sns
# %matplotlib inline

np.random.seed(42)

from physt import plotting

from bokeh.charts import output_notebook
output_notebook()
# Out:
# /home/pipek/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a0653361-268f-4644-ae7a-464284ca1534">Loading BokehJS ...</span>
#     </div>

# %%
# Some data
x = np.random.normal(100, 1, 10000)
y = np.random.normal(10, 10, 10000)

# %%
ax = h2(x, y, 11).plot(show_zero=False, alpha=0.5, text_alpha=1, show_values=True, cmap="Dark2", show_colorbar=False, transform=lambda x:1)
h2(x, y, 10).plot.image(cmap="rainbow", alpha=1, ax=ax, interpolation="lanczos", transform=np.sin)

# %%
h2(x, y, 40, name="Gauss").plot("image", cmap="rainbow", figsize=(5, 5))

# %%
plotting.matplotlib.bar3d(h2(x, y, 10, name="Gauss"), figsize=(5, 5), cmap="Accent");

# %%
h1(x, "human", 10, name="Gauss").plot(ylim=(100, 1020), cmap="Greys", ticks="edge", errors=True);

# %%
h1(x, "human", 200, name="Gauss").plot.line(errors=True, yscale="log")

# %%
h1(x, "human", 200, name="Gauss").plot.scatter(errors=True, xlim=(90, 100), stats_box=True)

# %%
h = h1(x, "human", 200, name="Gauss")
ax = h.plot("scatter", cumulative=True, s=3, transform=lambda x: np.sin(x / 500), cmap="rainbow")
# h.plot.line(ax=ax, cumulative=True)

# %%
h = h1(x, "human", 50, name="Gauss")
h.plot.scatter(backend="bokeh")
# Out:
#     <div class="plotdiv" id="31a71cb1-87e9-4533-8086-4c2c9df924ce"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("31a71cb1-87e9-4533-8086-4c2c9df924ce");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '31a71cb1-87e9-4533-8086-4c2c9df924ce' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1cc2e3c5-cb25-42cc-a2ba-6d70c6e6f55e":{"roots":{"references":[{"attributes":{"callback":null,"end":871.2,"start":-79.2},"id":"6da9a942-7cce-4e8f-9592-d4bc0889ec40","type":"Range1d"},{"attributes":{"axis_label":"x","formatter":{"id":"08954cd3-7bf7-421d-88c9-b3d29aa4b484","type":"BasicTickFormatter"},"plot":{"id":"7a41c7c5-84a5-482c-995f-824f781f579d","subtype":"Chart","type":"Plot"},"ticker":{"id":"b9f76d4a-f20d-49a7-803a-dd2b8e331574","type":"BasicTicker"}},"id":"3cffaa65-4d20-4458-abbd-04cee16cfa1d","type":"LinearAxis"},{"attributes":{"plot":{"id":"7a41c7c5-84a5-482c-995f-824f781f579d","subtype":"Chart","type":"Plot"}},"id":"b1c9aa20-a06d-440e-b63d-150ef1f10c40","type":"ResizeTool"},{"attributes":{},"id":"b9f76d4a-f20d-49a7-803a-dd2b8e331574","type":"BasicTicker"},{"attributes":{},"id":"282e8af7-85b7-4dd8-97ad-7390f96864f6","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"7a41c7c5-84a5-482c-995f-824f781f579d","subtype":"Chart","type":"Plot"},"ticker":{"id":"ca4bef80-dac3-4742-b96b-e49ae417797f","type":"BasicTicker"}},"id":"b0e2ae15-d849-489d-b567-e6d6b1475680","type":"Grid"},{"attributes":{"data_source":{"id":"a1e5eb51-92f7-419a-9952-4e98b669bcd5","type":"ColumnDataSource"},"glyph":{"id":"1d6c0069-2768-422b-acb6-7207d97452b3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ccd268ca-2dc8-4ca1-a4bc-abdcb321f953","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"1d6c0069-2768-422b-acb6-7207d97452b3","type":"Circle"},{"attributes":{"callback":null,"end":104.68,"start":95.32},"id":"07018558-a62f-45e4-b97b-8031f5cc9a22","type":"Range1d"},{"attributes":{"plot":{"id":"7a41c7c5-84a5-482c-995f-824f781f579d","subtype":"Chart","type":"Plot"}},"id":"ae2c7392-7c35-4925-ac8a-a92364b4bf18","type":"PreviewSaveTool"},{"attributes":{"overlay":{"id":"168a70c8-0ab6-45c2-a368-59fbc399591f","type":"BoxAnnotation"},"plot":{"id":"7a41c7c5-84a5-482c-995f-824f781f579d","subtype":"Chart","type":"Plot"}},"id":"52768add-6b11-4e88-a5d9-84c6c614f336","type":"BoxZoomTool"},{"attributes":{"axis_label":"y","formatter":{"id":"282e8af7-85b7-4dd8-97ad-7390f96864f6","type":"BasicTickFormatter"},"plot":{"id":"7a41c7c5-84a5-482c-995f-824f781f579d","subtype":"Chart","type":"Plot"},"ticker":{"id":"ca4bef80-dac3-4742-b96b-e49ae417797f","type":"BasicTicker"}},"id":"be0e7b66-4582-4b78-b1c0-32225380fe52","type":"LinearAxis"},{"attributes":{},"id":"ca4bef80-dac3-4742-b96b-e49ae417797f","type":"BasicTicker"},{"attributes":{},"id":"08954cd3-7bf7-421d-88c9-b3d29aa4b484","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"7a41c7c5-84a5-482c-995f-824f781f579d","subtype":"Chart","type":"Plot"},"ticker":{"id":"b9f76d4a-f20d-49a7-803a-dd2b8e331574","type":"BasicTicker"}},"id":"96da077a-6eee-47aa-9c28-37ab4029b319","type":"Grid"},{"attributes":{"below":[{"id":"3cffaa65-4d20-4458-abbd-04cee16cfa1d","type":"LinearAxis"}],"left":[{"id":"be0e7b66-4582-4b78-b1c0-32225380fe52","type":"LinearAxis"}],"legend":null,"renderers":[{"id":"168a70c8-0ab6-45c2-a368-59fbc399591f","type":"BoxAnnotation"},{"id":"ccd268ca-2dc8-4ca1-a4bc-abdcb321f953","type":"GlyphRenderer"},{"id":"3cffaa65-4d20-4458-abbd-04cee16cfa1d","type":"LinearAxis"},{"id":"be0e7b66-4582-4b78-b1c0-32225380fe52","type":"LinearAxis"},{"id":"96da077a-6eee-47aa-9c28-37ab4029b319","type":"Grid"},{"id":"b0e2ae15-d849-489d-b567-e6d6b1475680","type":"Grid"}],"title_text_font_size":{"value":"14pt"},"tool_events":{"id":"477dfd3d-04d8-469c-b5ce-73413d121720","type":"ToolEvents"},"tools":[{"id":"bddffc76-f2bf-4fa6-b04e-90d03ac0cbab","type":"PanTool"},{"id":"b341adc6-1c31-4286-831e-02de5f1c3f44","type":"WheelZoomTool"},{"id":"52768add-6b11-4e88-a5d9-84c6c614f336","type":"BoxZoomTool"},{"id":"ae2c7392-7c35-4925-ac8a-a92364b4bf18","type":"PreviewSaveTool"},{"id":"b1c9aa20 ...
