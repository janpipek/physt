# %% [markdown]
# # Plotting physt histograms

# %%
# Necessary import evil
import physt
from physt import h1, h2, histogramdd
import numpy as np
import matplotlib.pyplot as plt
import seaborn.apionly as sns
# %matplotlib inline

np.random.seed(42)

from physt import plotting

from bokeh.charts import output_notebook
output_notebook()
# Out:
# /home/pipek/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="63d4a01c-e8c7-4a34-84d2-c81d00b2968c">Loading BokehJS ...</span>
#     </div>

# %%
# Some data
x = np.random.normal(100, 1, 10000)
y = np.random.normal(10, 10, 10000)

# %%
ax = h2(x, y, 15).plot(figsize=(6, 6), show_zero=False, alpha=0, text_color="black", show_values=True, cmap="BuGn_r", show_colorbar=False, transform=lambda x:1)
h2(x, y, 20).plot.image(cmap="Spectral_r", alpha=1, ax=ax,  interpolation="lanczos")

# %%
h2(x, y, 40, name="Gauss").plot("image", cmap="rainbow", figsize=(5, 5))

# %%
plotting.matplotlib.bar3d(h2(x, y, 10, name="Gauss"), figsize=(5, 5), cmap="Accent");

# %%
h1(x, "human", 10, name="Gauss").plot(ylim=(100, 1020), cmap="Greys", ticks="edge", errors=True);

# %%
h1(x, "human", 200, name="Gauss").plot.line(errors=True, yscale="log")

# %%
h1(x, "human", 200, name="Gauss").plot.scatter(errors=True, xlim=(90, 100), stats_box=True)

# %%
h = h1(x, "human", 200, name="Gauss")
ax = h.plot("scatter", cumulative=True, s=3, transform=lambda x: np.sin(x / 500), cmap="rainbow")
# h.plot.line(ax=ax, cumulative=True)

# %%
h = h1(x, "human", 50, name="Gauss")
h.plot.scatter(backend="bokeh")
# Out:
#     <div class="plotdiv" id="42a1951a-25aa-47b5-a322-fcb6b3df5d7e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("42a1951a-25aa-47b5-a322-fcb6b3df5d7e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '42a1951a-25aa-47b5-a322-fcb6b3df5d7e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"37d4349a-d807-4c1e-8b6c-7886e9449339":{"roots":{"references":[{"attributes":{},"id":"343ebe6b-b6ab-4238-a2ac-910608f54806","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"1f4ce8c1-5fe9-49d5-990b-c64a19a371be","type":"BoxAnnotation"},"plot":{"id":"a30f6ea4-cd7c-4704-a1eb-b210feda5ade","subtype":"Chart","type":"Plot"}},"id":"2b5ed71e-967c-4184-85c3-10f29fd17da7","type":"BoxZoomTool"},{"attributes":{},"id":"7b2e6307-5f74-476c-95cb-5a94b47407d9","type":"BasicTicker"},{"attributes":{},"id":"d7874ce2-63d3-441d-af7a-792a07659667","type":"BasicTicker"},{"attributes":{"axis_label":"x","formatter":{"id":"bd988d4d-7a5c-4e1c-a742-886936562908","type":"BasicTickFormatter"},"plot":{"id":"a30f6ea4-cd7c-4704-a1eb-b210feda5ade","subtype":"Chart","type":"Plot"},"ticker":{"id":"7b2e6307-5f74-476c-95cb-5a94b47407d9","type":"BasicTicker"}},"id":"76d13d7c-a674-4508-b0f3-c9ff35b4abee","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"98673fb2-9574-449f-83a6-c10ae8cfa2a8","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"a30f6ea4-cd7c-4704-a1eb-b210feda5ade","subtype":"Chart","type":"Plot"},"ticker":{"id":"d7874ce2-63d3-441d-af7a-792a07659667","type":"BasicTicker"}},"id":"0fa6d30c-7cf2-4321-b155-040651b91aee","type":"Grid"},{"attributes":{"below":[{"id":"76d13d7c-a674-4508-b0f3-c9ff35b4abee","type":"LinearAxis"}],"left":[{"id":"78f291e7-0df9-4a07-912c-baeebc32241e","type":"LinearAxis"}],"legend":null,"renderers":[{"id":"1f4ce8c1-5fe9-49d5-990b-c64a19a371be","type":"BoxAnnotation"},{"id":"acebf4ba-6b2d-4120-b11b-40f282d07615","type":"GlyphRenderer"},{"id":"76d13d7c-a674-4508-b0f3-c9ff35b4abee","type":"LinearAxis"},{"id":"78f291e7-0df9-4a07-912c-baeebc32241e","type":"LinearAxis"},{"id":"ce356fd8-7158-482a-ba94-13a1845cfae6","type":"Grid"},{"id":"0fa6d30c-7cf2-4321-b155-040651b91aee","type":"Grid"}],"title_text_font_size":{"value":"14pt"},"tool_events":{"id":"05067f56-25be-4c46-a2e6-31529235dae1","type":"ToolEvents"},"tools":[{"id":"fcb648fc-03e8-4343-85c9-d3e8b143a040","type":"PanTool"},{"id":"684abc1d-8ad0-4246-b109-ef1d81062c91","type":"WheelZoomTool"},{"id":"2b5ed71e-967c-4184-85c3-10f29fd17da7","type":"BoxZoomTool"},{"id":"c167ed26-1d9e-4c80-ada3-785c43d6b368","type":"PreviewSaveTool"},{"id":"dac3ff82-7a5a-4a2d-bac6-e8ed802cb8b7","type":"ResizeTool"},{"id":"12d80288-3f13-4689-a387-fa878d8fa839","type":"ResetTool"},{"id":"cd683cb6-59e3-4c51-a36e-3ca098cdf34e","type":"HelpTool"}],"x_mapper_type":"auto","x_range":{"id":"d6c178da-9fba-4729-a46f-66b7569599c3","type":"Range1d"},"xscale":"auto","y_mapper_type":"auto","y_range":{"id":"2842dbaf-4744-4eac-96de-4477ccccbbec","type":"Range1d"},"yscale":"auto"},"id":"a30f6ea4-cd7c-4704-a1eb-b210feda5ade","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"end":871.2,"start":-79.2},"id":"2842dbaf-4744-4eac-96de-4477ccccbbec","type":"Range1d"},{"attributes":{"data_source":{"id":"a18633d9-f539-4d47-a435-76e19d1429cb","type":"ColumnDataSource"},"glyph":{"id":"98673fb2-9574-449f-83a6-c10ae8cfa2a8","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"acebf4ba-6b2d-4120-b11b-40f282d07615","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a30f6ea4-cd7c-4704-a1eb-b210feda5ade","subtype":"Chart","type":"Plot"}},"id":"dac3ff82-7a5a-4a2d-bac6-e8ed802cb8b7","type":"ResizeTool"},{"attributes":{"plot":{"id":"a30f6ea4-cd7c-4704-a1eb-b210feda5ade","subtype":"Chart","type":"Plot"}},"id":"c167ed26-1d9e-4c80-ada3-785c43d6b368","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"a30f6ea4-cd7c-4704-a1eb-b210feda5ade","subtype":"Chart","type":"Plot"}},"id":"684abc1d-8ad0-4246-b109-ef1d81062c91","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay" ...
