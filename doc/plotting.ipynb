# %% [markdown]
# # Plotting physt histograms
#
# Some matplotlib-based plotting examples, with no exhaustive documentation.

# %%
# Necessary import evil
import physt
from physt import h1, h2, h
from physt.plotting import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

from physt import plotting

# %%
# Some data
x = np.random.normal(10, 1, 10000)
y = np.random.normal(10, 10, 10000)

# %%
ax = h2(x, y, 15).plot(figsize=(6, 6), show_zero=False, alpha=0, text_color="black", show_values=True, cmap="BuGn_r", show_colorbar=False, transform=lambda x:1)
h2(x, y, 50).plot.image(cmap="Spectral_r", alpha=0.75, ax=ax)
# Out:
# <Axes: >

# %%
h2(x, y, 40, name="Gauss").plot("image", cmap="rainbow", figsize=(5, 5))
# Out:
# <Axes: >

# %%
plotting.matplotlib.bar3d(h2(x, y, 10, name="Gauss"), figsize=(5, 5), cmap="Accent");

# %%
h1(x, "pretty", bin_count=10, name="Gauss").plot(ylim=(100, 1020), cmap="Greys", ticks="edge", errors=True);

# %%
h1(x, "pretty", bin_count=200, name="Gauss").plot.line(errors=True, yscale="log")
# Out:
# <Axes: xlabel='axis0'>

# %%
h1(x, "pretty", bin_count=200, name="Gauss").plot.fill(lw=1, alpha=.4, figsize=(8, 4))
h1(x, "pretty", bin_count=200, name="Gauss").plot.fill(lw=1, alpha=.4, yscale="log", figsize=(8, 4), color="red")
# Out:
# <Axes: xlabel='axis0'>

# %%
h1(x, "pretty", bin_count=200, name="Gauss").plot.scatter(errors=True, xlim=(90, 100), show_stats="all")
# Out:
# <Axes: xlabel='axis0'>

# %%
ha = h1(x, "pretty", bin_count=20, name="Left")
hb = h1(x - 1 * np.sin(x / 12), "pretty", bin_count=40, name="Right")

from physt.plotting.matplotlib import pair_bars

# %%
pair_bars(ha, hb, density=True, errors=True, figsize=(5, 5));
# Out:
# C:\Users\janpi\Documents\code\physt\src\physt\histogram_base.py:389: UserWarning:
#
# Negative frequencies in the histogram.
#
# C:\Users\janpi\Documents\code\physt\src\physt\plotting\matplotlib.py:804: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %% [markdown]
# ## Example - histogram of time values

# %%
# Get values close to 
from physt.plotting.common import TimeTickHandler

data = np.random.normal(3600, 900, 4800)
H = h1(data, "pretty", axis_name="time")
H.plot(tick_handler=TimeTickHandler())
# Out:
# <Axes: xlabel='time'>
