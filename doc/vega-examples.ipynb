# %% [markdown]
# # Vega backend examples

# %%
from physt.examples import normal_h1, iris_h1, normal_h2, normal_h3, munros
from physt.plotting import set_default_backend

import numpy as np
np.random.seed(42)

set_default_backend("vega")

# %%
H = normal_h1()
H.plot.scatter()
# Out:
# <div class="vega-embed" id="4e179453-4c51-437f-998a-94499305aeae"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
H.plot.bar(cumulative=True, xlabel="Other label")
# Out:
# <div class="vega-embed" id="357e03a3-a88a-40c5-8a35-427c59714ca3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
H = iris_h1()
H.plot.line(cumulative=True)
# Out:
# <div class="vega-embed" id="a17417b2-bfe3-4576-94b4-7180349d5abf"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
H2 = munros().T
H2.plot(cmap="YellowGreen", show_values=True, height=333, width=333, show_zero=False)
# Out:
# <div class="vega-embed" id="298bd15e-0964-4d3c-ae1a-a0e5fbfa3855"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Example of an interactive 3D histogram
#
# **Note:** Unfortunately, this example does not render properly nor in GitHub renderer or notebook viewer. A live notebook must be running.

# %%
H3 = normal_h3()
H3.axis_names = ("first", "second", "third")
H3.plot(show_values=True, show_zero=False, cmap="Blues")
# Out:
# <div class="vega-embed" id="9dbb805a-240b-4548-add2-cf816fb885e3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
