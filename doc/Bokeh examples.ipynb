# %%
from bokeh.charts import Bar, show, output_notebook
from bokeh.models import HoverTool
import numpy as np
import physt
output_notebook()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
from physt import histogram

heights = [160, 155, 156, 198, 177, 168, 191, 183, 184, 179, 178, 172, 173, 175,
           172, 177, 176, 175, 174, 173, 174, 175, 177, 169, 168, 164, 175, 188,
           178, 174, 173, 181, 185, 166, 162, 163, 171, 165, 180, 189, 166, 163,
           172, 173, 174, 183, 184, 161, 162, 168, 169, 174, 176, 170, 169, 165]

hist = histogram(heights, range(150, 205, 5))

# %%
hist.plot("scatter", backend="bokeh");
# Out:
#     <div class="plotdiv" id="a73d17ab-d974-4fec-86f6-bb268cee57eb"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a73d17ab-d974-4fec-86f6-bb268cee57eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a73d17ab-d974-4fec-86f6-bb268cee57eb' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"77ef4068-6870-44de-aded-bc7b32d87da1": {"version": "0.11.0", "title": "Bokeh Application", "roots": {"references": [{"type": "Range1d", "id": "2e2c4610-693c-47de-87d9-133836fd665f", "attributes": {"callback": null, "start": -1.4000000000000001, "end": 15.4}}, {"type": "BoxZoomTool", "id": "342d9994-b572-4b33-a8bd-b53bcdeabe88", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}, "overlay": {"type": "BoxAnnotation", "id": "813a9356-84bc-4480-951f-f3f693bb4ac5"}}}, {"type": "PanTool", "id": "adc5f5ca-6a21-47e3-9473-3c9c496ca0a0", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}}}, {"type": "BasicTicker", "id": "cc9555cd-3d2c-4fb3-bccb-ef01c301bfc1", "attributes": {}}, {"type": "Range1d", "id": "5d4d0083-b497-42a9-a5ef-81a15160696c", "attributes": {"callback": null, "start": 148.0, "end": 202.0}}, {"type": "PreviewSaveTool", "id": "70751b9b-6e34-472e-a241-b52d0dc5fb17", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}}}, {"type": "Grid", "id": "b62cfe3d-11af-495a-a35d-01f46474d740", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}, "ticker": {"type": "BasicTicker", "id": "ab33f839-86b3-4bcd-94ce-1c729308879f"}}}, {"type": "ColumnDataSource", "id": "0f002505-f7b3-429b-ab72-02850cf596dd", "attributes": {"column_names": ["x_values", "y_values"], "data": {"x_values": [152.5, 157.5, 162.5, 167.5, 172.5, 177.5, 182.5, 187.5, 192.5, 197.5], "chart_index": [null, null, null, null, null, null, null, null, null, null], "y_values": [0.0, 2.0, 7.0, 10.0, 14.0, 12.0, 6.0, 3.0, 1.0, 1.0]}, "callback": null}}, {"type": "LinearAxis", "id": "21258f38-1e37-4fb5-985e-6b961869e1c8", "attributes": {"formatter": {"type": "BasicTickFormatter", "id": "f63b7560-6bf3-4716-a878-e8cf071f342c"}, "plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}, "axis_label": "y", "ticker": {"type": "BasicTicker", "id": "cc9555cd-3d2c-4fb3-bccb-ef01c301bfc1"}}}, {"type": "BasicTickFormatter", "id": "f63b7560-6bf3-4716-a878-e8cf071f342c", "attributes": {}}, {"type": "ToolEvents", "id": "8b1117bd-1f5d-4c35-b642-c9ec93596665", "attributes": {}}, {"type": "ResetTool", "id": "5b855c1a-8db0-4367-8b99-2c1114a6f62e", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}}}, {"type": "Grid", "id": "65f084ad-b9d5-4d48-adb8-cedbfa7c9be0", "attributes": {"dimension": 1, "plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}, "ticker": {"type": "BasicTicker", "id": "cc9555cd-3d2c-4fb3-bccb-ef01c301bfc1"}}}, {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a", "attributes": {"below": [{"type": "LinearAxis", "id": "5a5a5ce2-f394-4633-9ff4-d603d3c7df69"}], "renderers": [{"type": "BoxAnnotation", "id": "813a9356-84bc-4480-951f-f3f693bb4ac5"}, {"type": "GlyphRenderer", "id": "9da78718-9e61-49a4-8fc6-d1d9f58a3bf2"}, {"type": "LinearAxis", "id": "5a5a5ce2-f394-4633-9ff4-d603d3c7df69"}, {"type": "LinearAxis", "id": "21258f38-1e37-4fb5-985e-6b961869e1c8"}, {"type": "Grid", "id": "b62cfe3d-11af-495a-a35d-01f46474d740"}, {"type": "Grid", "id": "65f084ad-b9d5-4d48-adb8-cedbfa7c9be0"}], "x_range": {"type": "Range1d", "id": "5d4d0083-b497-42a9-a5ef-81a15160696c"}, "x_mapper_type": "auto", "left": [{"type": "LinearAxis", "id": "21258f38-1e37-4fb5-985e-6b961869e1c8"}], "xscale": "auto", "tool_events": {"type": "ToolEvents", "id": "8b1117bd-1f5d-4c35-b642-c9ec93596665"}, "legend": null, "title_text_font_size": {"value": "14pt"}, "y_mapper_type": "auto", "y_range": {"type": "Range1d", "id": "2e2c4610-693c-47de-87d9-133836fd665f"}, "tools": [{"type": "PanTool", "id": "adc5f5ca-6a21-47e3-9473-3c9c496ca0a0"}, {"type": "WheelZoomTool", "id": "1bfc85cd-0145-4456-8c50-ff3d692dc153"}, {"type": "BoxZoomTool ...

# %%
hist.plot(backend="bokeh", color="yellow");
# Out:
#     <div class="plotdiv" id="4b6cf3da-de77-4145-ad43-2547c71c47d2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4b6cf3da-de77-4145-ad43-2547c71c47d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4b6cf3da-de77-4145-ad43-2547c71c47d2' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ad83dd8d-be39-4553-bb95-65e25d3fd73c": {"version": "0.11.0", "title": "Bokeh Application", "roots": {"references": [{"type": "Quad", "id": "eaf6072c-9dc0-4459-a13c-f23d11082b7a", "attributes": {"right": {"field": "right"}, "left": {"field": "left"}, "bottom": {"field": "bottom"}, "top": {"field": "top"}, "fill_color": {"value": "yellow"}}}, {"type": "Range1d", "id": "2e2c4610-693c-47de-87d9-133836fd665f", "attributes": {"callback": null, "start": -1.4000000000000001, "end": 15.4}}, {"type": "BoxZoomTool", "id": "342d9994-b572-4b33-a8bd-b53bcdeabe88", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}, "overlay": {"type": "BoxAnnotation", "id": "813a9356-84bc-4480-951f-f3f693bb4ac5"}}}, {"type": "Plot", "subtype": "Figure", "id": "c6c7b3d2-0f69-4b45-b88a-6cb58ac80260", "attributes": {"below": [{"type": "LinearAxis", "id": "be90c925-a217-4e31-9c60-a6244e3f78f0"}], "renderers": [{"type": "LinearAxis", "id": "be90c925-a217-4e31-9c60-a6244e3f78f0"}, {"type": "Grid", "id": "f918f0d5-8156-4207-9962-32f8913af78f"}, {"type": "LinearAxis", "id": "cb52ac11-d35d-4609-8a89-561170eee28c"}, {"type": "Grid", "id": "601b1777-ced6-4b62-b42c-f1b8cad31135"}, {"type": "GlyphRenderer", "id": "4ea0008b-10ca-486f-aad5-fd6a63381d54"}], "x_range": {"type": "DataRange1d", "id": "13dbabf8-246b-48fc-b65f-a00648f8f58d"}, "left": [{"type": "LinearAxis", "id": "cb52ac11-d35d-4609-8a89-561170eee28c"}], "y_range": {"type": "DataRange1d", "id": "d6778e76-5153-4a15-829a-063ceec43eaf"}, "tools": [{"type": "HoverTool", "id": "3a09c28d-9c75-44ad-ba36-ac9cfb3320bc"}], "tool_events": {"type": "ToolEvents", "id": "9bf4b4f4-6f63-4a8a-b388-b840d85985da"}}}, {"type": "BasicTicker", "id": "cc9555cd-3d2c-4fb3-bccb-ef01c301bfc1", "attributes": {}}, {"type": "Range1d", "id": "5d4d0083-b497-42a9-a5ef-81a15160696c", "attributes": {"callback": null, "start": 148.0, "end": 202.0}}, {"type": "PreviewSaveTool", "id": "70751b9b-6e34-472e-a241-b52d0dc5fb17", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}}}, {"type": "Grid", "id": "b62cfe3d-11af-495a-a35d-01f46474d740", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}, "ticker": {"type": "BasicTicker", "id": "ab33f839-86b3-4bcd-94ce-1c729308879f"}}}, {"type": "Grid", "id": "601b1777-ced6-4b62-b42c-f1b8cad31135", "attributes": {"dimension": 1, "plot": {"type": "Plot", "subtype": "Figure", "id": "c6c7b3d2-0f69-4b45-b88a-6cb58ac80260"}, "ticker": {"type": "BasicTicker", "id": "8cb7fba6-8006-4538-a6df-fc50c749b4ad"}}}, {"type": "Grid", "id": "f918f0d5-8156-4207-9962-32f8913af78f", "attributes": {"plot": {"type": "Plot", "subtype": "Figure", "id": "c6c7b3d2-0f69-4b45-b88a-6cb58ac80260"}, "ticker": {"type": "BasicTicker", "id": "4024540a-88b0-478e-a24f-bd130d5d1605"}}}, {"type": "BasicTickFormatter", "id": "9f870304-231c-464e-88fd-b67ae409b1fe", "attributes": {}}, {"type": "ColumnDataSource", "id": "0f002505-f7b3-429b-ab72-02850cf596dd", "attributes": {"column_names": ["x_values", "y_values"], "data": {"x_values": [152.5, 157.5, 162.5, 167.5, 172.5, 177.5, 182.5, 187.5, 192.5, 197.5], "chart_index": [null, null, null, null, null, null, null, null, null, null], "y_values": [0.0, 2.0, 7.0, 10.0, 14.0, 12.0, 6.0, 3.0, 1.0, 1.0]}, "callback": null}}, {"type": "LinearAxis", "id": "21258f38-1e37-4fb5-985e-6b961869e1c8", "attributes": {"formatter": {"type": "BasicTickFormatter", "id": "f63b7560-6bf3-4716-a878-e8cf071f342c"}, "plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}, "axis_label": "y", "ticker": {"type": "BasicTicker", "id": "cc9555cd-3d2c-4fb3-bccb-ef01c301bfc1"}}}, {"type": "WheelZoomTool", "id": "1bfc85cd-0145-4456-8c50-ff3d692dc153", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}}}, {"type": "HoverTool", "id": "3a09c28d-9c75-44ad-ba36-ac9c ...

# %%
heights1 = histogram(np.random.normal(169, 10, 100000), bins=50, range=(150, 200))
heights2 = histogram(np.random.normal(180, 11, 100000), bins=50, range=(150, 200))

total = heights1 + heights2
figure = heights1.plot(backend="bokeh", color="red", show=False, alpha=0.5)
heights2.plot(backend="bokeh", color="blue", show=False, alpha=0.5, figure=figure)
total.plot(backend="bokeh", figure=figure, color="gray", alpha=0.5);
# Out:
#     <div class="plotdiv" id="6f87cfac-7603-4ce4-8329-4c5164491da0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6f87cfac-7603-4ce4-8329-4c5164491da0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6f87cfac-7603-4ce4-8329-4c5164491da0' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8629649c-0f40-491c-9137-17ecdb2f02f1": {"version": "0.11.0", "title": "Bokeh Application", "roots": {"references": [{"type": "Grid", "id": "f918f0d5-8156-4207-9962-32f8913af78f", "attributes": {"plot": {"type": "Plot", "subtype": "Figure", "id": "c6c7b3d2-0f69-4b45-b88a-6cb58ac80260"}, "ticker": {"type": "BasicTicker", "id": "4024540a-88b0-478e-a24f-bd130d5d1605"}}}, {"type": "LinearAxis", "id": "9e966845-886d-435c-b7f5-95e3b3826895", "attributes": {"formatter": {"type": "BasicTickFormatter", "id": "0ad61c73-ca75-4111-a2df-b7f85dc9c91b"}, "plot": {"type": "Plot", "subtype": "Figure", "id": "c51946f3-6f01-4a91-9eae-4c3b5f9ce790"}, "ticker": {"type": "BasicTicker", "id": "9ac9b6d0-856d-42a5-ad2a-63600679c4bf"}}}, {"type": "ToolEvents", "id": "9bf4b4f4-6f63-4a8a-b388-b840d85985da", "attributes": {}}, {"type": "GlyphRenderer", "id": "ff6dc519-ded1-4b8f-ada4-cb9de633bffe", "attributes": {"hover_glyph": null, "nonselection_glyph": {"type": "Quad", "id": "5275ea96-ad23-4679-b3f7-5ac004881351"}, "selection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "854bf235-f2fe-4ced-807a-e42cfae5c159"}, "glyph": {"type": "Quad", "id": "c178aa39-99c7-48d7-817a-3bd3d7b6e6ca"}}}, {"type": "LinearAxis", "id": "91033ed2-6318-4780-a23f-f8f352e410d4", "attributes": {"formatter": {"type": "BasicTickFormatter", "id": "193a1b83-2819-48fc-bf95-58e885db517a"}, "plot": {"type": "Plot", "subtype": "Figure", "id": "a6fa643e-229d-4eef-8846-1122acf6585b"}, "ticker": {"type": "BasicTicker", "id": "471cf651-68e9-44a8-b8be-24d4b82dc9be"}}}, {"type": "Quad", "id": "eaf6072c-9dc0-4459-a13c-f23d11082b7a", "attributes": {"right": {"field": "right"}, "left": {"field": "left"}, "bottom": {"field": "bottom"}, "top": {"field": "top"}, "fill_color": {"value": "yellow"}}}, {"type": "Grid", "id": "a4b8d5ca-6b63-416b-b83b-b50be3c23715", "attributes": {"plot": {"type": "Plot", "subtype": "Figure", "id": "c51946f3-6f01-4a91-9eae-4c3b5f9ce790"}, "ticker": {"type": "BasicTicker", "id": "9ac9b6d0-856d-42a5-ad2a-63600679c4bf"}}}, {"type": "LinearAxis", "id": "cb52ac11-d35d-4609-8a89-561170eee28c", "attributes": {"formatter": {"type": "BasicTickFormatter", "id": "9f870304-231c-464e-88fd-b67ae409b1fe"}, "plot": {"type": "Plot", "subtype": "Figure", "id": "c6c7b3d2-0f69-4b45-b88a-6cb58ac80260"}, "ticker": {"type": "BasicTicker", "id": "8cb7fba6-8006-4538-a6df-fc50c749b4ad"}}}, {"type": "HoverTool", "id": "29ff7703-ae85-4ea6-a27d-7329647629d4", "attributes": {"plot": {"type": "Plot", "subtype": "Figure", "id": "a81c0d01-e3ef-4e6f-bf06-fbf9497a5089"}, "callback": null, "tooltips": [["bin", "@left..@right"], ["frequency", "@top"]]}}, {"type": "BasicTickFormatter", "id": "2d810e72-bd7b-46b5-b475-87ec44a60262", "attributes": {}}, {"type": "PanTool", "id": "adc5f5ca-6a21-47e3-9473-3c9c496ca0a0", "attributes": {"plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}}}, {"type": "Grid", "id": "65f084ad-b9d5-4d48-adb8-cedbfa7c9be0", "attributes": {"dimension": 1, "plot": {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a"}, "ticker": {"type": "BasicTicker", "id": "cc9555cd-3d2c-4fb3-bccb-ef01c301bfc1"}}}, {"type": "BasicTicker", "id": "4024540a-88b0-478e-a24f-bd130d5d1605", "attributes": {}}, {"type": "DataRange1d", "id": "3827ace4-ef95-43ff-8c09-fe301d972b49", "attributes": {"callback": null}}, {"type": "Plot", "subtype": "Chart", "id": "414b4581-da5c-48c1-a591-e4b10bfe9a0a", "attributes": {"below": [{"type": "LinearAxis", "id": "5a5a5ce2-f394-4633-9ff4-d603d3c7df69"}], "renderers": [{"type": "BoxAnnotation", "id": "813a9356-84bc-4480-951f-f3f693bb4ac5"}, {"type": "GlyphRenderer", "id": "9da78718-9e61-49a4-8fc6-d1d9f58a3bf2"}, {"type": "LinearAxis", "id": "5a5a5ce2-f394-4633-9ff4-d603d3c7df69"}, {"type": "LinearAxis", "id": "21258f38-1e37-4fb5-985e-6b961869e1c8"}, {"type": "Grid", "id": "b62cfe3d-11af-495a-a35d-01f46474d740"}, {"type": "Grid", "id": "65f084ad-b9d5-4d48-adb8-cedbfa7c9 ...
