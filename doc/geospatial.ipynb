# %% [markdown]
# # Geospatial histogram visualization using folium
#
# **Note: You need to have the `folium` package installed to run this notebook.**
#
# ### "Bagging" the munros into rectangular bins
#
# *A Munro (About this sound listen (help·info)) is a mountain in Scotland with a height over 3,000 feet (914 m). Munros are named after Sir Hugh Munro, 4th Baronet (1856–1919), who produced the first list of such hills, known as Munro's Tables, in 1891...* says Wikipedia, more in https://en.wikipedia.org/wiki/Munro.
#
# Let's show the possibility to plot histograms in the maps with the help of folium library.

# %%
# Necessary import evil
import physt.plotting
physt.plotting.set_default_backend("folium")

# %%
# Read the data
from physt.examples import load_dataset
munros = load_dataset("munros")
munros.head()
# Out:
#                           name  height      long        lat
# 0                    Ben Nevis  1344.0 -5.003526  56.796834
# 1  Ben Macdui [Beinn Macduibh]  1309.0 -3.669100  57.070386
# 2                    Braeriach  1296.0 -3.728581  57.078177
# 3                   Cairn Toul  1291.0 -3.710790  57.054415
# 4        Sgor an Lochain Uaine  1258.0 -3.725797  57.058378

# %%
# How many of them are there? Wikipedia says 282 (as of 2017)
munros.shape
# Out:
# (282, 4)

# %% [markdown]
# ## How many munros are in each 10' rectangle?

# %%
hist = physt.h2(munros["lat"], munros["long"], "fixed_width", bin_width=1 / 6)

# %%
map = hist.plot()
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60be0a6562134631ba39c4c9d80ae45d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60be0a6562134631ba39c4c9d80ae45d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_60be0a6562134631ba39c4c9d80ae45d = L.map(
#                 &quot;map_60be0a6562134631ba39c4c9d80ae45d&quot;,
#                 {
#                     center: [57.33333333333333, -4.583333333333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_250b96d3b14c614ebd6844c9e180feda = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_60be0a6562134631ba39c4c9d80ae45d);
#
#
#         function geo_json_8f3e247b72f244dacf00796708ab8a9e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;8&quot;: case &quot;12&quot;: case &quot;22&quot;: case &quot;29&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;90&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;104&quot;: case &quot;113&quot;: case &quot;116&quot;: case &quot;119&quot;: case &quot;127&quot;: case &quot;134&quot;: case &quot;175&quot;: case &quot;199&quot;: case &quot;218&quot;: case &quot;263&quot;: case &quot;283&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edededff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;9&quot;: case &quot;28&quot;: case &quot;99&quot;: case &quot;109&quot;: case &quot;155&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b6b6b6ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;30&quot;: case &quot;48&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;55&quot;: case &quot;72&quot;: case &quot;95&quot;: case &quot;117&quot;: case &quot;131&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c9c9c9ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;31&quot;: case &quot;120&quot;: case &quot;133&quot;: case &quot;197&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6d6d6dff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;49&quot;: case &quot;94&quot;: case &quot;101&quot;: case &quot;110&quot;: case &quot;121&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7f7f7fff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;50&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#494949ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;54&quot;: case &quot;102&quot;: case &quot;111&quot;: case &quot;132&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#5b5b5bff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;70&quot;: case &quot;195&quot;: case &quot;196&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#929292ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;71&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#000000ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;73&quot;: case &quot;96&quot;: case &quot;100&quot;: case &quot;153&quot;: case &quot;154&quot;: case &quot;173&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a4a4a4ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;74&quot;: case &quot;78&quot;: case &quot;89&quot;: case &quot;112&quot;: case &quot;122&quot;: case &quot;152&quot;: case &quot;172&quot;: case &quot;194&quot;: case &quot;239&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dbdbdbff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;we

# %%
# Now, let's combine this information with positions of the 20 tallest
import folium
map = hist.plot()
for i, row in munros.iloc[:20].iterrows():
    marker = folium.Marker([row["lat"], row["long"]], popup="{0} ({1} m)".format(row["name"], row["height"]))
    marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd1127e1242b5454f47ccaa65961cdf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd1127e1242b5454f47ccaa65961cdf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fd1127e1242b5454f47ccaa65961cdf0 = L.map(
#                 &quot;map_fd1127e1242b5454f47ccaa65961cdf0&quot;,
#                 {
#                     center: [57.33333333333333, -4.583333333333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68872ba61794ec4eed42352ef50908f8 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd1127e1242b5454f47ccaa65961cdf0);
#
#
#         function geo_json_5a7957a35977f61ad234957879819b09_styler(feature) {
#             switch(feature.id) {
#                 case &quot;8&quot;: case &quot;12&quot;: case &quot;22&quot;: case &quot;29&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;90&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;104&quot;: case &quot;113&quot;: case &quot;116&quot;: case &quot;119&quot;: case &quot;127&quot;: case &quot;134&quot;: case &quot;175&quot;: case &quot;199&quot;: case &quot;218&quot;: case &quot;263&quot;: case &quot;283&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edededff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;9&quot;: case &quot;28&quot;: case &quot;99&quot;: case &quot;109&quot;: case &quot;155&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b6b6b6ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;30&quot;: case &quot;48&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;55&quot;: case &quot;72&quot;: case &quot;95&quot;: case &quot;117&quot;: case &quot;131&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c9c9c9ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;31&quot;: case &quot;120&quot;: case &quot;133&quot;: case &quot;197&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6d6d6dff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;49&quot;: case &quot;94&quot;: case &quot;101&quot;: case &quot;110&quot;: case &quot;121&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7f7f7fff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;50&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#494949ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;54&quot;: case &quot;102&quot;: case &quot;111&quot;: case &quot;132&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#5b5b5bff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;70&quot;: case &quot;195&quot;: case &quot;196&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#929292ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;71&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#000000ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;73&quot;: case &quot;96&quot;: case &quot;100&quot;: case &quot;153&quot;: case &quot;154&quot;: case &quot;173&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a4a4a4ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;74&quot;: case &quot;78&quot;: case &quot;89&quot;: case &quot;112&quot;: case &quot;122&quot;: case &quot;152&quot;: case &quot;172&quot;: case &quot;194&quot;: case &quot;239&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dbdbdbff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;we
